# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Line Chart

# %%
yield_apples = [0.89,0.91,0.92,0.93,0.94,0.95]

# %% [markdown]
# After we define the data points of apple yields,we are going to plot its line chart using matplotlib

# %%
plt.plot(yield_apples)

# %% [markdown]
# To better understand the graph and its purpose, we can add the x-axis values too

# %%
years = [2017,2018,2019,2020,2021,2022]
yield_apples = [0.89,0.91,0.92,0.93,0.94,0.95]

# %% [markdown]
# Since we have the years variable as the x-axis,we need to type it before the yield_apples variable being

# %%
plt.plot(years , yield_apples)

# %% [markdown]
# #Task 1

# %%
film = ['Titanic','Avatar 2','Saw X','The Nun 2']
rating= [3.7, 3.5, 3.6, 2.7]

# %%
plt.plot(film , rating)

# %% [markdown]
# Let's add lable to the axes so that we can show what each axis represents

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
apples =[0.89,0.91,0.93,0.97,0.986,0.943]
tangerines = [0.79,0.61,0.93,0.97,0.962,0.931]

# %%
plt.plot(years,apples)
plt.plot(years, tangerines)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# #Task 2

# %%
Film = ['Titanic','Avatar 2','Saw X','The Nun 2']
Week_1= [3.7, 3.5, 3.6, 2.7]
Week_2= [3.8, 3.6, 3.7, 2.9]

# %%
plt.plot(film,Rate_1)
plt.plot(film,Rate_2)
plt.xlabel('Title')
plt.ylabel('Rate');

# %% [markdown]
# We can add a legend which tells us what each line in our graph means.To understand what we are ploting,we can add a title to our graph.

# %%
plt.plot(years,apples)
plt.plot(years,tangerines)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop yields in Kanto")
plt.legend(['Apples', 'Tangerines'])

# %% [markdown]
# To show each data point on our graph,we can highlight them with markers using the marker argument.Many differentshapes like a circle,cross,square,diamond,etc are provided by matplotlib

# %%
plt.plot(years, apples, marker = 'o')
plt.plot(years, tangerines, marker = 'x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop yields in Kanto")
plt.legend(['Apples', 'Tangerines'])

# %% [markdown]
# You can use the plt.figure function to change the size of the figure

# %%
plt.figure(figsize =(12,6))

plt.plot(years, tangerines, marker ='o')
plt.title('Yield of Tangerines (tons per hectare)')
# Out:
# Text(0.5, 1.0, 'Yield of Tangerines (tons per hectare)')

# %% [markdown]
# #Task 3

# %%
Film = ['Titanic','Avatar 2','Saw X','The Nun 2']
Rate_1= [3.7, 3.5, 3.6, 2.7]
Rate_2= [3.8, 3.6, 3.7, 2.9]

# %%
plt.plot(Film,Rate_1)
plt.plot(Film,Rate_2)

plt.xlabel('Title')
plt.ylabel('Rate');

plt.title("Film Terlaris")
plt.legend(['Rate_1', 'Rate_2'])

# %%
plt.plot(Film,Rate_1,marker = 'o')
plt.plot(Film,Rate_2, marker = 'x')

plt.xlabel('Title')
plt.ylabel('Rate');

plt.title("Film Terlaris")
plt.legend(['Rate_1', 'Rate_2'])

# %% [markdown]
# Task 4

# %%
sns.set_style("whitegrid")

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years, apples, marker = 'o')
plt.plot(years, tangerines, marker = 'x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop yields in Kanto")
plt.legend(['Apples', 'Tangerines'])

# %%
sns.set_style("whitegrid")

# %%
plt.plot(Film,Rate_1,marker = 'o')
plt.plot(Film,Rate_2, marker = 'x')

plt.xlabel('Title')
plt.ylabel('Rate');

plt.title("Film Terlaris")
plt.legend(['Rate_1', 'Rate_2'])

# %%
sns.set_style("darkgrid")

# %%
plt.plot(Film,Rate_1,marker = 'o')
plt.plot(Film,Rate_2, marker = 'x')

plt.xlabel('Title')
plt.ylabel('Rate');

plt.title("Film Terlaris")
plt.legend(['Rate_1', 'Rate_2'])

# %%
import pandas as pd

# %%
crops_yield = dict(tahun=years,apel=apples,jeruk=tangerines)
data_panen = pd.DataFrame(crops_yield)

# %%
data_panen
# Out:
#    tahun   apel  jeruk
# 0   2017  0.890  0.790
# 1   2018  0.910  0.610
# 2   2019  0.930  0.930
# 3   2020  0.970  0.970
# 4   2021  0.986  0.962
# 5   2022  0.943  0.931

# %%
ax = sns.lineplot(x ='tahun',y='apel',data = data_panen)
ax1 = sns.lineplot(x ='tahun',y='apel',data = data_panen)
plt.show()

# %%
film_data = dict(Film=Film,Rate_1=Rate_1,Rate_2=Rate_2)
data_film = pd.DataFrame(film_data)

# %%
data_film
# Out:
#         Film  Rate_1  Rate_2
# 0    Titanic     3.7     3.8
# 1   Avatar 2     3.5     3.6
# 2      Saw X     3.6     3.7
# 3  The Nun 2     2.7     2.9

# %%
ax = sns.lineplot(x ='Film',y='Rate_1',data = data_film)
ax1 = sns.lineplot(x ='Film',y='Rate_1',data = data_film)
plt.show()

# %% [markdown]
# # Bar Graph

# %% [markdown]
# Using Matplotlib

# %%
plt.bar(years, tangerines)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
# Out:
# Text(0.5, 1.0, 'Crop Yields in Kanto')

# %%
plt.bar(years , apples)
plt.bar(years, tangerines, bottom=apples)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# TASK 1

# %%
plt.bar(Film, Rate_2)

plt.xlabel('Title')
plt.ylabel('Rate')

plt.title('Rating Film Per Minggu')
# Out:
# Text(0.5, 1.0, 'Rating Film Per Minggu')

# %%
plt.bar(Film, Rate_1)
plt.bar(Film, Rate_2, bottom = Rate_1)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Using Seaborn

# %%
tips_df = sns.load_dataset("tips")
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# We can draw a bar chart to visualize how the average bill amount varies across different days of the week.We can do this by computing the day wiseaverages and then using plt.bar.The seaborn library also provides a barplot function that can automatically compute averages.

# %%
sns.barplot(x ='day',
           y = 'total_bill',
           data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# TASK 2

# %%
flights_df = sns.load_dataset("flights")
flights_df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.barplot(x ='month',
           y = 'passengers',
           data=flights_df)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %% [markdown]
# # Histogram

# %%
iris_df = sns.load_dataset('iris')
iris_df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# Using Matplotlib

# %%
iris_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width")
plt.hist(iris_df.sepal_width)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
#Sepecifiying the number of bins
plt.hist(iris_df.sepal_width, bins=10);

# %% [markdown]
# TASK 3

# %%
plt.title("Total passengers")
plt.hist(flights_df.passengers, bins =10)
# Out:
# (array([24., 27., 19., 18., 22., 13., 10.,  6.,  3.,  2.]),
#  array([104. , 155.8, 207.6, 259.4, 311.2, 363. , 414.8, 466.6, 518.4,
#         570.2, 622. ]),
#  <BarContainer object of 10 artists>)
